# %% [markdown]
# <a href="https://colab.research.google.com/github/shahvatsal712/Python/blob/main/Tic_Tac_Toe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Creating Tic Tac Toe Project game

# %%
from IPython.display import clear_output
#write a function that can print out a board. Set up your voard as a list, where each index -9 correspinds with a number on a number pad, so you get a 3x3 board representation.
def display_board(board):
  clear_output()
  print('   |   |')
  print(' ' + board[7] + ' | ' + board[8] + ' | ' + board[9])
  print('   |   |')
  print('------------')
  print('   |   |')
  print(' ' + board[4] + ' | ' + board[5] + ' | ' + board[6])
  print('   |   |')
  print('------------')
  print(' ' + board[1] + ' | ' + board[2] + ' | ' + board[3])
  print('   |   |')

# %%
#run your function on a test version of the board list and make adjustments as necessary
test_board = ['#','X','O','X','O','X','O','X','O','X']
display_board(test_board)
display_board(test_board)
# Out:
#    |   |
#  X | O | X
#    |   |
# ------------
#    |   |
#  O | X | O
#    |   |
# ------------
#  X | O | X
#    |   |

# %%
#write a function that can take in a player intput and assign their marker as 'X' or 'O'. Think about using while loops to continually ask until you get a correct andwer.

def player_input():
  '''
  output = (player 1 marker, player 2 marker)
  '''
  marker  = ''
  while not (marker == 'X' or marker == 'O'):
    marker = input('Player 1: Choose X or O: ').upper()

  if marker == 'X':
    return ('X', 'O')
  else:
    return ('O', 'X')

# %%
player1_marker, player2_marker = player_input()
# Out:
# Player 1: Choose X or O: X

# %%
player1_marker
# Out:
# 'X'

# %%
#write a funtion that takes in the board list object, a market('X' or 'O') and a  desired postion (number 1-9) and assigns it to the board.
def place_marker(board, marker, position):
  board[position] = marker

# %%
place_marker(test_board,'$',8)
display_board(test_board)
# Out:
#    |   |
#  X | $ | X
#    |   |
# ------------
#    |   |
#  O | X | O
#    |   |
# ------------
#  X | O | X
#    |   |

# %%
#write a function that takes in a board and a mark (X or O) and then checks to see if that mark has won.

def win_check(board, mark):
  #win tic tac toe?
  return((board[1] == board[2] == board[3] == mark) or
  (board[4] == board[5] == board[6] == mark) or
  (board[7] == board[8] == board[9] == mark) or
  (board[7] == board[4] == board[1] == mark) or
  (board[8] == board[5] == board[2] == mark) or
  (board[9] == board[6] == board[3] == mark) or
  (board[7] == board[5] == board[3] == mark) or
  (board[9] == board[5] == board[1] == mark))

# %%
display_board(test_board)
win_check(test_board,'X')
# Out:
#    |   |
#  X | $ | X
#    |   |
# ------------
#    |   |
#  O | X | O
#    |   |
# ------------
#  X | O | X
#    |   |
# True

# %%
#write a function that usess the random module to randomly decide which player goes first. You may want to look up random.randint() return a string of which player went first.

import random
def choose_first():
  flip = random.randint(0,1)
  if flip == 0:
    return 'Player 1'
  else:
    return 'Player 2'

# %%
#write a function that returns a boolean indicating whether a space on the board is freely available.

def space_check(board, position):
  return board[position] == ' '

# %%
#write a function that checks if the board is full and returns a boolean value. True if full, False otherwise.
def full_board_check(board):
  for i in range(1,10):
    if space_check(board, i):
      return False
  return True #board is full when return True

# %%
#write a function that asks for a player's next position (as a number 1-9) and then uses the function from step 6 to check if it's a free position. If it is, then return the position for later use.

def player_choice(board):
  position = 0

  while position not in [1,2,3,4,5,6,7,8,9] or not space_check(board, position):
    position = int(input('Choose a position: (1-9) '))

  return position

# %%
#write a function that asks the player if they want to play again and returns a boolean True if they do want to play again.

def replay():
  choice = input("Play again? Enter Yes or No")
  return choice == 'Yes'

# %%
#run the game

print('Welcome to Tic Tac Toe')

while True:
  #play the game


  # set everything up (board, whos first, choose markets X,O)
  the_board = [' ']*10
  player1_marker, player2_marker = player_input()

  turn = choose_first()
  print(turn + ' will go first')

  play_game = input('Ready to play? y or n?')
  if play_game == 'y':
    game_on = True
  else:
    game_on = False

  #game play
  while game_on:
    if turn == 'Player 1':
      display_board(the_board)
      position = player_choice(the_board)
      place_marker(the_board, player1_marker, position)

      if win_check(the_board, player1_marker):
        display_board(the_board)
        print('PLAYER 1 HAS WON!!')
        game_on = False

      else:
        if full_board_check(the_board):
          display_board(the_board)
          print("TIE GAME!")
          game_on = False
        else:
          turn = 'Player 2'

    else:
      display_board(the_board)
      position = player_choice(the_board)
      place_marker(the_board, player2_marker, position)

      if win_check(the_board, player2_marker):
          display_board(the_board)
          print('PLAYER 2 HAS WON!!')
          game_on = False

      else:
          if full_board_check(the_board):
            display_board(the_board)
            print("TIE GAME!")
            game_on = False
          else:
            turn = 'Player 1'


  if not replay():
      break




  #player one turn


  #player two turn
# Out:
#    |   |
#    |   |
#    |   |
# ------------
#    |   |
#    |   |
#    |   |
# ------------
#  O | X | O
#    |   |
